# %% [markdown]
# # 関連時系列を使ったバージョン

# %% [markdown]
# # Kaggle提出用ファイルを作成する

# %% [markdown]
# # 1.S3からforecast結果をdownload

# %%
# !aws s3 cp --recursive s3://work-kaggle-ohio/store-sales-time-series-forecasting/export_forecast_tgt_rlt/ ../result_forecast_tgt_rlt/
# Out:
# download: s3://work-kaggle-ohio/store-sales-time-series-forecasting/export_forecast_tgt_rlt/kaggle_sales_tgt_rlt_2022-01-20T13-43-27Z_part0.csv to ../result_forecast_tgt_rlt/kaggle_sales_tgt_rlt_2022-01-20T13-43-27Z_part0.csv
# download: s3://work-kaggle-ohio/store-sales-time-series-forecasting/export_forecast_tgt_rlt/_CHECK to ../result_forecast_tgt_rlt/_CHECK
# download: s3://work-kaggle-ohio/store-sales-time-series-forecasting/export_forecast_tgt_rlt/kaggle_sales_tgt_rlt_2022-01-20T13-43-27Z_part100.csv to ../result_forecast_tgt_rlt/kaggle_sales_tgt_rlt_2022-01-20T13-43-27Z_part100.csv
# download: s3://work-kaggle-ohio/store-sales-time-series-forecasting/export_forecast_tgt_rlt/_SUCCESS to ../result_forecast_tgt_rlt/_SUCCESS
# download: s3://work-kaggle-ohio/store-sales-time-series-forecasting/export_forecast_tgt_rlt/kaggle_sales_tgt_rlt_2022-01-20T13-43-27Z_part1.csv to ../result_forecast_tgt_rlt/kaggle_sales_tgt_rlt_2022-01-20T13-43-27Z_part1.csv
# ...

# %% [markdown]
# ## データ結合

# %%
import glob
import pandas as pd

df = pd.DataFrame()

files = glob.glob("../result_forecast_tgt_rlt/*.csv")
for file in files:
    #print(file)
    df_tmp = pd.read_csv(file)
    df = pd.concat([df,df_tmp]).reset_index(drop=True)

# %%
df
# Out:
#          item_id                  date  store_nbr          p10          p50  \
# 0      beverages  2017-08-16T00:00:00Z         36  2262.031021  3009.069656
# 1      beverages  2017-08-17T00:00:00Z         36  2256.266597  3077.821545
# 2      beverages  2017-08-18T00:00:00Z         36  2272.565834  3070.466037
# 3      beverages  2017-08-19T00:00:00Z         36  2764.037151  3630.943688
# 4      beverages  2017-08-20T00:00:00Z         36  2828.150709  3775.789176
# ...          ...                   ...        ...          ...          ...
# 28507    seafood  2017-08-27T00:00:00Z         28     2.164328     7.638127
# 28508    seafood  2017-08-28T00:00:00Z         28    -1.529725     3.950719
# 28509    seafood  2017-08-29T00:00:00Z         28    -0.604704     4.882388
# 28510    seafood  2017-08-30T00:00:00Z         28    -2.931443     2.562277
# 28511    seafood  2017-08-31T00:00:00Z         28    -2.990883     2.509457
#
#                p90
# 0      3822.574292
# ...

# %% [markdown]
# ## 提出用ファイルに整形

# %%
df_sub = pd.read_csv('../input/sample_submission.csv')

# %%
df_sub
# Out:
#             id  sales
# 0      3000888    0.0
# 1      3000889    0.0
# 2      3000890    0.0
# 3      3000891    0.0
# 4      3000892    0.0
# ...        ...    ...
# 28507  3029395    0.0
# 28508  3029396    0.0
# 28509  3029397    0.0
# 28510  3029398    0.0
# 28511  3029399    0.0
#
# [28512 rows x 2 columns]

# %%
df_test = pd.read_csv('../input/test.csv')

# %%
print(df_test.nunique())
print(df_test['date'].min())
print(df_test['date'].max())
print(54*33*16)
# Out:
# id             28512
# date              16
# store_nbr         54
# family            33
# onpromotion      212
# dtype: int64
# 2017-08-16
# 2017-08-31
# 28512

# %% [markdown]
# # dfを提出用に加工していく

# %%
df
# Out:
#          item_id                  date  store_nbr          p10          p50  \
# 0      beverages  2017-08-16T00:00:00Z         36  2262.031021  3009.069656
# 1      beverages  2017-08-17T00:00:00Z         36  2256.266597  3077.821545
# 2      beverages  2017-08-18T00:00:00Z         36  2272.565834  3070.466037
# 3      beverages  2017-08-19T00:00:00Z         36  2764.037151  3630.943688
# 4      beverages  2017-08-20T00:00:00Z         36  2828.150709  3775.789176
# ...          ...                   ...        ...          ...          ...
# 28507    seafood  2017-08-27T00:00:00Z         28     2.164328     7.638127
# 28508    seafood  2017-08-28T00:00:00Z         28    -1.529725     3.950719
# 28509    seafood  2017-08-29T00:00:00Z         28    -0.604704     4.882388
# 28510    seafood  2017-08-30T00:00:00Z         28    -2.931443     2.562277
# 28511    seafood  2017-08-31T00:00:00Z         28    -2.990883     2.509457
#
#                p90
# 0      3822.574292
# ...

# %%
df['family'] = df['item_id'].str.upper()
df['date'] = df['date'].str[0:10]
df['sales'] = df['p50']

# %%
df
# Out:
#          item_id        date  store_nbr          p10          p50  \
# 0      beverages  2017-08-16         36  2262.031021  3009.069656
# 1      beverages  2017-08-17         36  2256.266597  3077.821545
# 2      beverages  2017-08-18         36  2272.565834  3070.466037
# 3      beverages  2017-08-19         36  2764.037151  3630.943688
# 4      beverages  2017-08-20         36  2828.150709  3775.789176
# ...          ...         ...        ...          ...          ...
# 28507    seafood  2017-08-27         28     2.164328     7.638127
# 28508    seafood  2017-08-28         28    -1.529725     3.950719
# 28509    seafood  2017-08-29         28    -0.604704     4.882388
# 28510    seafood  2017-08-30         28    -2.931443     2.562277
# 28511    seafood  2017-08-31         28    -2.990883     2.509457
#
#                p90     family        sales
# 0      3822.574292  BEVERAGES  3009.069656
# 1      4020.284493  BEVERAGES  3077.821545
# ...

# %%
df_mrg = pd.merge(df_test, df, how='left', on=['date', 'store_nbr', 'family'])

# %%
df_mrg[['id' ,'sales']].to_csv('../submit/sub_forecast_tgt_rlt.csv', index=False)

# %% [markdown]
# # !!!!!! 予測期間16日じゃないかあああああああ

# %%
df_test['item_id'] = df_test['family'].str.lower()

# %%
df_test
# Out:
#             id        date  store_nbr                      family  \
# 0      3000888  2017-08-16          1                  AUTOMOTIVE
# 1      3000889  2017-08-16          1                   BABY CARE
# 2      3000890  2017-08-16          1                      BEAUTY
# 3      3000891  2017-08-16          1                   BEVERAGES
# 4      3000892  2017-08-16          1                       BOOKS
# ...        ...         ...        ...                         ...
# 28507  3029395  2017-08-31          9                     POULTRY
# 28508  3029396  2017-08-31          9              PREPARED FOODS
# 28509  3029397  2017-08-31          9                     PRODUCE
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES
# 28511  3029399  2017-08-31          9                     SEAFOOD
#
#        onpromotion                     item_id
# 0                0                  automotive
# 1                0                   baby care
# ...

# %%
df.head()
# Out:
#   item_id                  date  store_nbr       p10       p50       p90
# 0  beauty  2017-08-16T00:00:00Z         25  0.750166  2.789812  4.635010
# 1  beauty  2017-08-17T00:00:00Z         25 -0.135176  2.517841  4.884029
# 2  beauty  2017-08-18T00:00:00Z         25  0.326958  4.131533  7.308528
# 3  beauty  2017-08-19T00:00:00Z         25  0.329145  3.246138  7.528454
# 4  beauty  2017-08-20T00:00:00Z         25  0.874725  4.269231  6.614688

# %%
df['date'] = df['date'].str.replace('T',' ').str.replace(' 00:00:00Z','')

# %%
df['sales'] = df['p50']

# %%
df.head()
# Out:
#   item_id        date  store_nbr       p10       p50       p90     sales
# 0  beauty  2017-08-16         25  0.750166  2.789812  4.635010  2.789812
# 1  beauty  2017-08-17         25 -0.135176  2.517841  4.884029  2.517841
# 2  beauty  2017-08-18         25  0.326958  4.131533  7.308528  4.131533
# 3  beauty  2017-08-19         25  0.329145  3.246138  7.528454  3.246138
# 4  beauty  2017-08-20         25  0.874725  4.269231  6.614688  4.269231

# %%
pd.merge(df, df_test[['date','item_id','store_nbr','id']], how='left', on=['date','item_id','store_nbr'])
# Out:
#        item_id        date  store_nbr       p10        p50        p90  \
# 0       beauty  2017-08-16         25  0.750166   2.789812   4.635010
# 1       beauty  2017-08-17         25 -0.135176   2.517841   4.884029
# 2       beauty  2017-08-18         25  0.326958   4.131533   7.308528
# 3       beauty  2017-08-19         25  0.329145   3.246138   7.528454
# 4       beauty  2017-08-20         25  0.874725   4.269231   6.614688
# ...        ...         ...        ...       ...        ...        ...
# 26725  seafood  2017-08-26          5  4.574191  10.245558  14.601978
# 26726  seafood  2017-08-27          5  5.298670  11.445668  16.342670
# 26727  seafood  2017-08-28          5  1.914506   8.073844  12.953550
# 26728  seafood  2017-08-29          5  1.306258   7.617987  12.674770
# 26729  seafood  2017-08-30          5  3.952590   9.397840  14.650101
#
#            sales       id
# 0       2.789812  3001451
# 1       2.517841  3003233
# 2       4.131533  3005015
# ...

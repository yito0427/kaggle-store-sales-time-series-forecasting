# %% [markdown]
# # Forecastで最もよかった、0.39633と、codeで一番高いスコアを平均する
#
# 0.40419
# https://www.kaggle.com/andrej0marinchenko/hyperparamaters

# %% [markdown]
# # 読み込み

# %%
import pandas as pd

# %%
df1 = pd.read_csv('../submit/sub_forecast_16days_only_target_log1p.csv')

df2 = pd.read_csv('../submit_downloaded/submission_Hyperparamaters_0.40419.csv')

# %%
df1
# Out:
#             id        sales
# 0      3000888     4.153817
# 1      3000889    -0.009198
# 2      3000890     3.481955
# 3      3000891  2058.320538
# 4      3000892     0.012338
# ...        ...          ...
# 28507  3029395   311.835297
# 28508  3029396    94.041445
# 28509  3029397  1119.140393
# 28510  3029398    98.337095
# 28511  3029399    14.494569
#
# [28512 rows x 2 columns]

# %%
df2
# Out:
#             id        sales
# 0      3000888     4.101210
# 1      3000889     0.000000
# 2      3000890     4.555177
# 3      3000891  2262.699439
# 4      3000892     0.083691
# ...        ...          ...
# 28507  3029395   367.115985
# 28508  3029396   109.489971
# 28509  3029397  1336.562983
# 28510  3029398   136.896222
# 28511  3029399    14.133084
#
# [28512 rows x 2 columns]

# %%
df_mrg = df1.merge(df2, on=['id'])

# %%
df_mrg['sales'] = (df_mrg['sales_x'] + df_mrg['sales_y']) / 2

# %%
df_mrg.plot.scatter(x='sales_x', y='sales_y', figsize=(15,15), grid=True)

# %% [markdown]
# # 出力

# %%
df_mrg[['id' ,'sales']].to_csv('../submit/sub_ensemble_foretgtonlylog1p_kagglenotebest.csv', index=False)
